# %%
#text to image

# %%
# !pip install diffusers

# %%
from diffusers import DiffusionPipeline
import torch

# %%
pipe=DiffusionPipeline.from_pretrained ("stabilityai/stable-diffusion-xl-base-1.0",  torch_dtype=torch.float16,  use_safetensors=True,  variant="fp16")
pipe.to("cuda")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# Fetching 19 files:   0%|          | 0/19 [00:00<?, ?it/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...

# %%
prompt="monkey with bannana"

# %%
images=pipe(prompt=prompt,
            num_inference_steps=100,
            guidance_scale=9).images[0]
images
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
# !pip install modelscope
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118  # For CUDA 11.8
# !pip install imageio imageio-ffmpeg
# Out:
# ...
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
from huggingface_hub import snapshot_download
from modelscope.pipelines import pipeline
from modelscope.outputs import OutputKeys
import pathlib
# Out:
# 2025-05-30 10:02:10,725 - modelscope - INFO - PyTorch version 2.6.0+cu124 Found.
# 2025-05-30 10:02:10,728 - modelscope - INFO - TensorFlow version 2.18.0 Found.
# 2025-05-30 10:02:10,728 - modelscope - INFO - Loading ast index from /root/.cache/modelscope/ast_indexer
# 2025-05-30 10:02:10,729 - modelscope - INFO - No valid ast index found from /root/.cache/modelscope/ast_indexer, generating ast index from prebuilt!
# 2025-05-30 10:02:10,781 - modelscope - INFO - Loading done! Current index file version is 1.4.2, with md5 f116f480c6b79dae49935fbe04809f4e and a total number of 842 components indexed

# %%
model_dir=pathlib.Path('weights')
snapshot_download('damo-vilab/modelscope-damo-text-to-video-synthesis',repo_type='model',local_dir=model_dir)
# Out:
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# text2video_pytorch_model.pth:   0%|          | 0.00/5.65G [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# configuration.json:   0%|          | 0.00/1.07k [00:00<?, ?B/s]
# VQGAN_autoencoder.pth:   0%|          | 0.00/5.21G [00:00<?, ?B/s]
# open_clip_pytorch_model.bin:   0%|          | 0.00/3.94G [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.49k [00:00<?, ?B/s]
# '/content/weights'

# %%
from modelscope.pipelines import pipeline
from modelscope.outputs import OutputKeys

# Load pipeline with the pretrained model
pipe = pipeline(
    task='text-to-video-synthesis',
    model='damo-vilab/text-to-video-synthesis'
)

# Define your prompt
prompt = {'text': 'A flying monkey'}

# Run the model
output = pipe(prompt)

# Output the path to the generated video
print('Video saved at:', output[OutputKeys.OUTPUT_VIDEO])
# Out:
# 2025-05-30 10:17:39,762 - modelscope - INFO - PyTorch version 2.6.0+cu124 Found.
# 2025-05-30 10:17:39,767 - modelscope - INFO - TensorFlow version 2.18.0 Found.
# 2025-05-30 10:17:39,768 - modelscope - INFO - Loading ast index from /root/.cache/modelscope/ast_indexer
# 2025-05-30 10:17:39,889 - modelscope - INFO - Loading done! Current index file version is 1.4.2, with md5 f116f480c6b79dae49935fbe04809f4e and a total number of 842 components indexed
# module 'numpy' has no attribute 'dtypes'
# 2025-05-30 10:17:48,434 - modelscope - ERROR - Authentication token does not exist, failed to access model damo-vilab/text-to-video-synthesis which may not exist or may be                 private. Please login first.
# ERROR:modelscope:Authentication token does not exist, failed to access model damo-vilab/text-to-video-synthesis which may not exist or may be                 private. Please login first.
# ...
